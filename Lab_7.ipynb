# %% [markdown]
# <a href="https://colab.research.google.com/github/Samak1234/algorithmslab/blob/main/Lab_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Greedy Knapsack Problem (Fractional)
# In this lab, we explore the Fractional Knapsack Problem, a fundamental optimization problem that demonstrates the Greedy Algorithmic Paradigm.
# We will implement it using greedy selection (based on value-to-weight ratio) and analyze its time and space complexity.

# %% [markdown]
# - Created by Dr. Ajay

# %% [markdown]
# # Problem Definition
# Given a set of
# n
# n items, each with:
# Value vi
# Weight wi
# A knapsack with maximum capacity **W**
#
# Goal: maximize total value that can be put in the knapsack.
# Constraint: You may take fractions of items.
#
# Greedy Strategy:
#
# *  Sort items by decreasing ratio vi/wi
# *  Select items fully until knapsack is full.
# *  Take fraction of the next item if capacity remains.

# %%
def fractional_knapsack(values, weights, capacity):
    n = len(values)


    items = []
    for i in range(n):
        items.append((values[i], weights[i], values[i] / weights[i]))
    #append function jo hai list ke end me element add kar deta hai
    items.sort(key=lambda x: x[2], reverse=True)
    #idhar par ham sort kar rahe hai items ko decreasing order mein
    total_value = 0.0

    for value, weight, ratio in items:
        if capacity >= weight:
            total_value += value
            capacity -= weight
        else:
            total_value += value * (capacity / weight)
            break

    return total_value

values = [60, 100, 120]
weights = [10, 20, 30]
capacity = 50

result = fractional_knapsack(values, weights, capacity)
print("Maximum value:", result)

# %% [markdown]
# 1.Calculate ratio (v/w) for each item
#
# 2. Sort items in decreasing order of ratio
# 3. total_value = 0
#
# 4. for each item:
#       if weight <= capacity:
#             take full item
#             subtract weight from capacity
#             add full value
#       else:
#             take fraction
#             add fractional value
#             break
#
#
# 1.   List item
# 2.   List item

# %%
def fractional_knapsack_from_pseudocode(values, weights, capacity):
    items = []
    for i in range(len(values)):
        items.append((values[i], weights[i], values[i] / weights[i]))

    items.sort(key=lambda x: x[2], reverse=True)

    total_value = 0.0

    for value, weight, ratio in items:

        if capacity >= weight:
            total_value += value
            capacity -= weight

        else:
            total_value += value * (capacity / weight)
            capacity = 0
            break
    return total_value


values = [60, 100, 120]
weights = [10, 20, 30]
capacity = 50

result_pseudocode = fractional_knapsack_from_pseudocode(values, weights, capacity)
print("Maximum value (from pseudocode implementation):", result_pseudocode)
# Out:
# Maximum value (from pseudocode implementation): 240.0

# %% [markdown]
# In this lab, we implement Huffman Coding, a greedy algorithm used for lossless data compression.
# It assigns variable-length binary codes to input symbols based on their frequencies, ensuring that more frequent symbols receive shorter codes and less frequent symbols receive longer codes.
#
# This algorithm constructs a binary tree (Huffman Tree) where each leaf node represents a character, and the path from the root to a leaf gives the character’s binary code.
#
# Use:
# Huffman Tree Construction using a Min-Priority Queue (Min-Heap).
# Code generation for each character.
# Encoding and decoding using the generated Huffman codes.
# Complexity analysis and comparison with fixed-length encoding.
#
# # Pseudocode:
# 1. Create a leaf node for each character and insert all nodes into a
# 2. min-heap by frequency.
#    *  While the heap has more than one node:
#    * Extract two nodes with the lowest frequencies.
#    * Create a new internal node with frequency = sum of the two.
#    *  Set the two extracted nodes as left and right children.
#    *  Insert the new node back into the min-heap.
# 3. The remaining node is the root of the Huffman Tree.
#
# 4. Traverse the tree:
#    * Assign 0 for left edge and 1 for right edge.
#    * The resulting paths from root to leaves give Huffman codes.

# %%
import heapq


class HuffmanNode:
    def __init__(self, char, freq):
        self.char = char
        self.freq = freq
        self.left = None
        self.right = None


    def __lt__(self, other):
        return self.freq < other.freq


def build_huffman_tree(frequencies):

    priority_queue = []
    for char, freq in frequencies.items():
        heapq.heappush(priority_queue, HuffmanNode(char, freq))


    while len(priority_queue) > 1:

        node1 = heapq.heappop(priority_queue)
        node2 = heapq.heappop(priority_queue)


        merged_node = HuffmanNode(None, node1.freq + node2.freq)
        merged_node.left = node1
        merged_node.right = node2


        heapq.heappush(priority_queue, merged_node)


    return priority_queue[0]


def generate_huffman_codes(root):
    huffman_codes = {}

    def _traverse(node, current_code):
        if node is None:
            return


        if node.char is not None:
            huffman_codes[node.char] = current_code if current_code else '0'
            return


        _traverse(node.left, current_code + '0')
        _traverse(node.right, current_code + '1')

    _traverse(root, '')
    return huffman_codes


frequencies = {'a': 5, 'b': 9, 'c': 12, 'd': 13, 'e': 16, 'f': 45}


huffman_tree_root = build_huffman_tree(frequencies)


hc = generate_huffman_codes(huffman_tree_root)

print("Huffman Codes:")
for char, code in hc.items():
    print(f"{char}: {code}")


def encode_text(text, huffman_codes):
    encoded_text = ""
    for char in text:
        encoded_text += huffman_codes[char]
    return encoded_text

def decode_text(encoded_text, huffman_tree_root):
    decoded_text = ""
    current_node = huffman_tree_root
    for bit in encoded_text:
        if bit == '0':
            current_node = current_node.left
        else:
            current_node = current_node.right

        if current_node.char is not None:
            decoded_text += current_node.char
            current_node = huffman_tree_root
    return decoded_text


input_text = "abcdef"
encoded_message = encode_text(input_text, hc)
print(f"\nOriginal text: {input_text}")
print(f"Encoded message: {encoded_message}")

decoded_message = decode_text(encoded_message, huffman_tree_root)
print(f"Decoded message: {decoded_message}")
# Out:
# Huffman Codes:
# f: 0
# c: 100
# d: 101
# a: 1100
# b: 1101
# e: 111
#
# Original text: abcdef
# Encoded message: 110011011001011110
# Decoded message: abcdef
