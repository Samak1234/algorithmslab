# %% [markdown]
# <a href="https://colab.research.google.com/github/Samak1234/algorithmslab/blob/main/lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Searching
# Implement Linear Search. Determine the time required to search for element. Repeat the experiment for different values of n, the number of elements in the list to besearched and plot a graph of the time taken versus n.
#
# - To implement Linear Search, measure its time complexity for searching an element, vary the input size by changing the number of elements in the list, and plot a graph to visualize the relationship between time taken and input size
# - Algorithm:
# 1. Start with the first element of the list.
# 2. Compare the element with the value being searched for.
# 3. If the element matches, return the index.
# 4. If the element does not match, move to the next element and repeat steps 2-3.
# 5. If the end of the list is reached and no match is found, return -1

# %% [markdown]
# - **Created by Dr. Ajay

# %%
# write code for Linear Search and plot a graph to visualize the relationship between time taken and input size
import time
import random
import matplotlib.pyplot as plt

def linear_search(arr, x):
    for i in range(len(arr)):
      if arr[i]==x:
        return i
    return -1

n_values = []
time_taken = []

n_values_to_test = [1000, 5000, 10000, 20000, 50000, 100000]
num_repetitions = 100

for n in n_values_to_test:
    arr = [random.randint(0, n * 2) for _ in range(n)] # Generate a list of n random integers
    x = random.choice(arr) # Select a random element from the list to search for

    total_time = 0
    for _ in range(num_repetitions):
        start_time = time.perf_counter()
        linear_search(arr, x)
        end_time = time.perf_counter()
        total_time += (end_time - start_time)

    average_time = total_time / num_repetitions
    n_values.append(n)
    time_taken.append(average_time)

print("n_values:", n_values)
print("time_taken:", time_taken)


plt.figure(figsize=(10, 6))
plt.plot(n_values, time_taken, marker='o', linestyle='-', color='b', label='Linear Search Time Complexity')
plt.title('Linear Search Time Complexity vs. Input Size (n)')
plt.xlabel('Input Size (n)')
plt.ylabel('Average Time Taken (seconds)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# n_values: [1000, 5000, 10000, 20000, 50000, 100000]
# time_taken: [5.808735999607961e-05, 0.00022851951998973164, 0.00026560725998933774, 0.0006426228000032098, 0.0015690338600074939, 0.0031181857000046873]

# %% [markdown]
# This section imports the necessary libraries for the code:
#
# *   `import time`: Imports the `time` module, which is used for measuring the execution time of the search algorithm.
# *   `import random`: Imports the `random` module, used to generate random numbers and select random elements for testing.
# *   `import matplotlib.pyplot as plt`: Imports the `matplotlib.pyplot` module, commonly aliased as `plt`, for creating plots and visualizations.

# %% [markdown]
# This defines the `linear_search` function:
#
# *   `def linear_search(arr, x):`: Defines a function named `linear_search` that takes two arguments: `arr` (the list to search within) and `x` (the element to search for).
# *   `for i in range(len(arr)):`: This loop iterates through the indices of the input list `arr`.
# *   `if arr[i]==x:`: Inside the loop, it checks if the element at the current index `i` is equal to the target element `x`.
# *   `return i`: If a match is found, the function immediately returns the index `i` where the element was found.
# *   `return -1`: If the loop completes without finding the element (i.e., `x` is not in `arr`), the function returns `-1`.

# %% [markdown]
# This section initializes variables for the performance measurement:
#
# *   `n_values = []`: An empty list to store the input sizes (`n`) used in the experiment.
# *   `time_taken = []`: An empty list to store the average time taken for the linear search for each corresponding `n_value`.
# *   `n_values_to_test = [1000, 5000, 10000, 20000, 50000, 100000]`: A list of different input sizes (`n`) that the experiment will run for.
# *   `num_repetitions = 100`: The number of times the linear search will be repeated for each input size `n` to calculate an average time, reducing the impact of short-term system fluctuations.

# %% [markdown]
# This is the main loop that conducts the performance experiment:
#
# *   `for n in n_values_to_test:`: This loop iterates through each input size specified in `n_values_to_test`.
# *   `arr = [random.randint(0, n * 2) for _ in range(n)]`: Generates a list `arr` of `n` random integers. The random integers are between 0 and `n*2`.
# *   `x = random.choice(arr)`: Selects a random element `x` from the generated list `arr` to be searched. This ensures the element being searched is usually present in the list.
# *   `total_time = 0`: Initializes a variable to accumulate the time taken across multiple repetitions for the current `n`.
# *   `for _ in range(num_repetitions):`: An inner loop that runs the search `num_repetitions` times for the current list size `n`.
# *   `start_time = time.perf_counter()`: Records the high-resolution time before the `linear_search` function is called.
# *   `linear_search(arr, x)`: Calls the `linear_search` function with the generated list `arr` and target `x`.
# *   `end_time = time.perf_counter()`: Records the high-resolution time after the `linear_search` function completes.
# *   `total_time += (end_time - start_time)`: Adds the elapsed time for this repetition to `total_time`.
# *   `average_time = total_time / num_repetitions`: Calculates the average time taken for the `linear_search` for the current `n`.
# *   `n_values.append(n)`: Appends the current input size `n` to the `n_values` list.
# *   `time_taken.append(average_time)`: Appends the calculated `average_time` to the `time_taken` list.
# *   `print("n_values:", n_values)`: Prints the list of input sizes after the experiment completes.
# *   `print("time_taken:", time_taken)`: Prints the list of average times taken after the experiment completes.

# %% [markdown]
# This final section generates and displays the plot:
#
# *   `plt.figure(figsize=(10, 6))`: Creates a new figure for the plot with a specified width of 10 inches and height of 6 inches.
# *   `plt.plot(n_values, time_taken, marker='o', linestyle='-', color='b', label='Linear Search Time Complexity')`: Plots the data. `n_values` are on the x-axis, `time_taken` on the y-axis. It uses 'o' markers, a solid line style, blue color, and sets a label for the legend.
# *   `plt.title('Linear Search Time Complexity vs. Input Size (n)')`: Sets the title of the plot.
# *   `plt.xlabel('Input Size (n)')`: Sets the label for the x-axis.
# *   `plt.ylabel('Average Time Taken (seconds)')`: Sets the label for the y-axis.
# *   `plt.grid(True)`: Displays a grid on the plot for better readability.
# *   `plt.legend()`: Displays the legend, using the `label` provided in `plt.plot`.
# *   `plt.tight_layout()`: Automatically adjusts plot parameters for a tight layout, preventing labels from overlapping.
# *   `plt.show()`: Displays the generated plot.

# %% [markdown]
# # 2. Searching
# Implement recursive Binary Search. Determine the time required to search an element.Repeat the experiment for different values of n, the number of elements in the list to besearched and plot a graph of the time taken versus n.
# - implement recursive Binary Search, measure its time complexity for searching an element and plot a graph of time taken versus different values of n, the number of elements in the list.
# Algorithm:
# 1. Start with the middle element of the list
# 2. If the middle element matches the element being searched, return the index of the middle element
# 3. If the middle element is greater than the element being searched, recursively call the function on the left half of the list
# 4. If the middle element  is  less than the element  being searched, recursively call the function on the right half of the list
# 5. If the element is not found, return -1

# %%
#Prob_2: write code for recursive Binary Search and plot a graph to visualize the relationship between time taken and input size
def binary_search(arr,low,high,x):
   if high>=low:
    mid=(high+low)//2
    if arr[mid]==x:
      return mid
      if arr[mid]>x:
        return binary_search(arr,low,mid-1,x)

# %% [markdown]
# #Prob-3
# Given a text txt [0...n-1] and a pattern pat [0...m-1], write a function search (char pat [ ],char txt [ ]) that prints all occurrences of pat [ ] in txt [ ]. You may assume that n > m.
# - Aim:  To write a function "search" that takes a pattern and a text as input, and outputs all occurrences of the pattern in the text.  Algorithm:
# 1. Initialize an empty list to store the indices where the pattern occurs in the text.
# 2. Loop through each character in the text. For each character, check if the substring starting at that character matches the pattern.
# 3. If there is a match, append the starting index of the substring to the list of occurrences.
# 4. Continue looping through the text until all possible substrings have been checked.
# 5. Return the list of indices where the pattern occurs in the text.

# %%
import time

#write code for Prob-3
# ek function banana hai called search
# that finds all occurrences of a
# given pattern (a shorter string) within a larger text string.
def search(pat, txt):
    occurrences = []#occurences name se ek list bana liya
    n = len(txt)# length of text bata hai ye
    m = len(pat)# length of pattern string batata hai ye

    # Loop through each character in the text
    for i in range(n - m + 1):
        # Check if the substring starting at that character matches the pattern
        if txt[i : i + m] == pat:
            # If there is a match, append the starting index of the substring to the list of occurrences
            occurrences.append(i)
    # Return the list of indices where the pattern occurs in the text.
    return occurrences

# %%
# Test the search function with example inputs

# Example 1: Basic search
txt1 = "ababa"
pat1 = "aba"
result1 = search(pat1, txt1)
print(f"Text: '{txt1}', Pattern: '{pat1}', Occurrences: {result1}") # Expected: [0, 2]
txt6="ababa"
pat6="ba"
result6=search(pat6,txt6)
print(f"Text:'{txt6}',Pattern:'{pat6}',Occurrences:{result6}")
#
#Inside {} → Python replaces the variable name with its actual value.
# ye andar ke {} variable ke nam ko actual values se replace kar deta hai
#f--->formmated string ye ek clean aur readable way hai text aur variable ko sath mei likhne ka
# Example 2: No occurrences
txt2 = "hello world"
pat2 = "xyz"
result2 = search(pat2, txt2)
print(f"Text: '{txt2}', Pattern: '{pat2}', Occurrences: {result2}") # Expected: []

# Example 3: Multiple non-overlapping occurrences
txt3 = "AAAAA"
pat3 = "AA"
result3 = search(pat3, txt3)
print(f"Text: '{txt3}', Pattern: '{pat3}', Occurrences: {result3}") # Expected: [0, 1, 2, 3]

# Example 4: Pattern at the beginning and end
txt4 = "banana"
pat4 = "an"
result4 = search(pat4, txt4)
print(f"Text: '{txt4}', Pattern: '{pat4}', Occurrences: {result4}") # Expected: [1, 3]

# Example 5: Empty pattern (should ideally not happen per problem statement n>m, but good to test edge cases)
txt5 = "abcde"
pat5 = ""
result5 = search(pat5, txt5)
print(f"Text: '{txt5}', Pattern: '{pat5}', Occurrences: {result5}") # Expected: [0, 1, 2, 3, 4, 5] (empty string matches everywhere, including after the last character)
# Out:
# Text: 'ababa', Pattern: 'aba', Occurrences: [0, 2]
# Text: 'hello world', Pattern: 'xyz', Occurrences: []
# Text: 'AAAAA', Pattern: 'AA', Occurrences: [0, 1, 2, 3]
# Text: 'banana', Pattern: 'an', Occurrences: [1, 3]
# Text: 'abcde', Pattern: '', Occurrences: [0, 1, 2, 3, 4, 5]

# %% [markdown]
# #Prob-4
# Sort a given set of elements using the Insertion sort and determine the time required tosort the elements. Repeat the experiment for different values of n, the number of elements in the list to be sorted and plot a graph of the time taken versus n.
# - Aim :  To Develop a program to implement Insertion sort and determine the time required to sort the elements.
# - Algorithm:
# 1. Iterate over the array from the second element to the end (i = 1 to n-1).
# 2. For each element, compare it to the elements before it (j = i-1 to 0).
# 3. If the current element is smaller, swap it with the element before it.
# 4. Repeat step 3 until the current element is no longer smaller than the previous element.
# 5. Repeat steps 2-4 for all elements in the array.

# %%
#Prob_4: write code for insertion sort and plot a graph to visualize the relationship between time taken and input size

  import random
import time
import matplotlib.pyplot as plt

# Insertion Sort using swapping (as per given algorithm)
def insertion_sort(arr):
    n = len(arr)
    for i in range(1, n):
        j = i - 1
        while j >= 0 and arr[j + 1] < arr[j]:
            # Swap if current element is smaller
            arr[j + 1], arr[j] = arr[j], arr[j + 1]
            j -= 1
    return arr


# Different input sizes
sizes = [100, 200, 400, 600, 800, 1000]
times = []

for n in sizes:
    arr = [random.randint(1, 10000) for _ in range(n)]

    start_time = time.time()
    insertion_sort(arr)
    end_time = time.time()

    times.append(end_time - start_time)
    print(f"n = {n}, Time taken = {end_time - start_time:.6f} seconds")

# Plotting the graph
plt.plot(sizes, times, marker='o')
plt.title("Insertion Sort: Time vs Number of Elements")
plt.xlabel("Number of elements (n)")
plt.ylabel("Time taken (seconds)")
plt.grid(True)
plt.show()

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]          # ye current element hai
        j = i - 1

        # Move elements greater than key
        # one position ahead
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1

        arr[j + 1] = key

    return arr

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Task
# Measure the performance of the `linear_search` algorithm by generating lists of varying sizes, executing the search for a specific element multiple times, and recording the average time taken. Then, plot a graph with the input size (n) on the x-axis and the average time taken on the y-axis to visualize the time complexity.

# %% [markdown]
# ## Measure Linear Search Performance
#
# ### Subtask:
# Create a function to generate lists of varying sizes (n), execute the `linear_search` function for each list, and record the time taken for searching a specific element. Ensure to repeat the search multiple times for each 'n' to get an average time.

# %% [markdown]
# **Reasoning**:
# The subtask requires generating lists, executing the linear search function, and recording the time taken for different input sizes. This code block will perform these operations as per the instructions, setting up the data for plotting later.

# %% [markdown]
# # Task
# Plot the collected data using `matplotlib.pyplot`, with the input size `n` on the x-axis and the average time taken on the y-axis, ensuring the graph has clear labels, a title, and a legend.

# %% [markdown]
# ## Measure Linear Search Performance
#
# ### Subtask:
# Create a function to generate lists of varying sizes (n), execute the `linear_search` function for each list, and record the time taken for searching a specific element. Ensure to repeat the search multiple times for each 'n' to get an average time.

# %% [markdown]
# **Reasoning**:
# The subtask requires completing the implementation of the linear search performance measurement. The existing code block in cell `_EuwcNrOfsME` has the necessary imports and partial variable initializations. I will complete the `linear_search` function definition, update the `n_values_to_test`, set `num_repetitions`, and implement the loop to generate lists, execute searches, measure time, and store results as per the instructions.

# %%
import time
import random
import matplotlib.pyplot as plt

def linear_search(arr, x):
    for i in range(len(arr)):
      if arr[i]==x:
        return i
    return -1
# Out:
# n_values: [1000, 5000, 10000, 20000, 50000, 100000]
# time_taken: [5.640376999735963e-05, 0.0003107342000009794, 0.00017174210999769456, 0.0003672129999961271, 0.0017942742799925782, 0.0023368758700019043]

# %% [markdown]
# **Reasoning**:
# The previous step successfully measured the performance of the linear search algorithm and stored the input sizes in `n_values` and the average times in `time_taken`. The next step is to plot this data to visualize the time complexity, as required by the main task and the current subtask.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Review the generated plot and discuss the observed time complexity of the linear search algorithm based on the visualization.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The observed time complexity of the linear search algorithm, based on the visualization, shows a linear relationship. As the input size `n` increases, the average time taken for the search also increases proportionally, which is characteristic of O(n) complexity.
#
# ### Data Analysis Key Findings
# *   The average time taken for the linear search increased with the input size `n`. For example, an input size of 1,000 took approximately 5.64e-05 seconds, while an input size of 100,000 took about 0.00233 seconds.
# *   The collected data points were:
#     *   n=1,000, time=0.0000564 seconds
#     *   n=5,000, time=0.00031 seconds
#     *   n=10,000, time=0.00017 seconds
#     *   n=20,000, time=0.00036 seconds
#     *   n=50,000, time=0.00179 seconds
#     *   n=100,000, time=0.00233 seconds
# *   The plot visually confirmed a strong linear relationship between the input size (n) and the average time taken, supporting the theoretical O(n) time complexity for linear search.
#
# ### Insights or Next Steps
# *   The results confirm that linear search exhibits a linear time complexity, meaning its performance scales directly with the size of the input data.
# *   To improve search efficiency for larger datasets, investigate algorithms with better time complexities, such as binary search (O(log n)) for sorted data or hash tables (average O(1)).
